# %%
import pandas as pd
import numpy as np
# !pip install datasets
# Out:
# Collecting datasets
#   Using cached datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Using cached xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Using cached multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2024.10.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.28.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.11.13)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.18.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 7.2 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 8.1 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 11.2 MB/s eta 0:00:00
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-3.6.0 dill-0.3.8 multiprocess-0.70.16 xxhash-3.5.0

# %%
# Import the necessary module
from google.colab import drive
from datasets import Dataset
from datasets import load_from_disk

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load the dataset from disk *after* mounting Google Drive
dataset = load_from_disk('file:///content/drive/MyDrive/my_dataset')

# %%
train_ds = pd.DataFrame(dataset['train'])
test_ds = pd.DataFrame(dataset['test'])

# %%
train_ds
# Out:
#                                               document  \
# 0    National Archives \n \n Yes, it’s that time ag...
# 1    LOS ANGELES (AP) — In her first interview sinc...
# 2    GAITHERSBURG, Md. (AP) — A small, private jet ...
# 3    Tucker Carlson Exposes His Own Sexism on Twitt...
# 4    A man accused of removing another man's testic...
# ..                                                 ...
# 995  _______ |_ _| | | | | ____| | | | | | | | \___...
# 996  RAMALLAH, West Bank (AP) — A witness says a me...
# 997  If you’ve ever thought that your birth control...
# 998  Friends say surprise reconciliation is on the ...
# 999  In 2005, the Witherspoon School of Law and Pub...
#
#                                                summary  \
# 0    – The unemployment rate dropped to 8.2% last m...
# 1    – Shelly Sterling plans "eventually" to divorc...
# 2    – A twin-engine Embraer jet that the FAA descr...
# 3    – Tucker Carlson is in deep doodoo with conser...
# 4    – What are the three most horrifying words in ...
# ..                                                 ...
# 995  – Before dying by car bomb last October, Malte...
# 996  – A Palestinian Cabinet member has died amid a...
# 997  – Anyone who's struggled with mood swings whil...
# 998  – The faces of Demi and Ashton may be filling ...
# 999  – A pregnant Alabama woman who suffered a misc...
#
#                                      document_no_punct  \
# 0    National Archives \n \n Yes it’s that time aga...
# 1    LOS ANGELES AP — In her first interview since ...
# 2    GAITHERSBURG Md AP — A small private jet has c...
# 3    Tucker Carlson Exposes His Own Sexism on Twitt...
# 4    A man accused of removing another mans testicl...
# ..                                                 ...
# 995                  ournalist Nedim Turfent was re...
# 996  RAMALLAH West Bank AP — A witness says a membe...
# 997  If you’ve ever thought that your birth control...
# 998  Friends say surprise reconciliation is on the ...
# 999  In 2005 the Witherspoon School of Law and Publ...
#
#                                    document_tokenizedt  \
# 0    [national, archives, yes, it’s, that, time, ag...
# 1    [los, angeles, ap, —, in, her, first, intervie...
# 2    [gaithersburg, md, ap, —, a, small, private, j...
# 3    [tucker, carlson, exposes, his, own, sexism, o...
# 4    [a, man, accused, of, removing, another, mans,...
# ..                                                 ...
# 995  [ournalist, nedim, turfent, was, reporting, on...
# 996  [ramallah, west, bank, ap, —, a, witness, says...
# 997  [if, you’ve, ever, thought, that, your, birth,...
# 998  [friends, say, surprise, reconciliation, is, o...
# 999  [in, 2005, the, witherspoon, school, of, law, ...
#
#                                       document_no_stop  \
# 0    [national, archives, yes, it’s, time, folks, i...
# 1    [los, angeles, ap, —, first, interview, since,...
# 2    [gaithersburg, md, ap, —, small, private, jet,...
# 3    [tucker, carlson, exposes, sexism, twitter, up...
# 4    [man, accused, removing, another, mans, testic...
# ..                                                 ...
# 995  [ournalist, nedim, turfent, reporting, brutal,...
# 996  [ramallah, west, bank, ap, —, witness, says, m...
# 997  [you’ve, ever, thought, birth, control, might,...
# 998  [friends, say, surprise, reconciliation, cards...
# 999  [2005, witherspoon, school, law, public, polic...
#
#                                       document_stemmed  \
# 0    [nation, archiv, ye, it’, time, folk, it’, fir...
# 1    [lo, angel, ap, —, first, interview, sinc, nba...
# 2    [gaithersburg, md, ap, —, small, privat, jet, ...
# 3    [tucker, carlson, expos, sexism, twitter, upda...
# 4    [man, accus, remov, anoth, man, testicl, meet,...
# ..                                                 ...
# 995  [ournalist, nedim, turfent, report, brutal, co...
# 996  [ramallah, west, bank, ap, —, wit, say, member...
# 997  [you’v, ever, thought, birth, control, might, ...
# 998  [friend, say, surpris, reconcili, card, hollyw...
# 999  [2005, witherspoon, school, law, public, polic...
#
#                                  document_lemmatized_v  \
# 0    [national, archive, yes, it’s, time, folks, it...
# 1    [los, angeles, ap, —, first, interview, since,...
# 2    [gaithersburg, md, ap, —, small, private, jet,...
# 3    [tucker, carlson, expose, sexism, twitter, upd...
# 4    [man, accuse, remove, another, man, testicle, ...
# ..                                                 ...
# 995  [ournalist, nedim, turfent, report, brutal, co...
# 996  [ramallah, west, bank, ap, —, witness, say, me...
# 997  [you’ve, ever, think, birth, control, might, m...
# 998  [friends, say, surprise, reconciliation, card,...
# 999  [2005, witherspoon, school, law, public, polic...
#
#                                  document_lemmatized_a  \
# 0    [national, archives, yes, it’s, time, folks, i...
# 1    [los, angeles, ap, —, first, interview, since,...
# 2    [gaithersburg, md, ap, —, small, private, jet,...
# 3    [tucker, carlson, exposes, sexism, twitter, up...
# 4    [man, accused, removing, another, mans, testic...
# ..                                                 ...
# 995  [ournalist, nedim, turfent, reporting, brutal,...
# 996  [ramallah, west, bank, ap, —, witness, says, m...
# 997  [you’ve, ever, thought, birth, control, might,...
# 998  [friends, say, surprise, reconciliation, cards...
# 999  [2005, witherspoon, school, law, public, polic...
#
#                                  document_lemmatized_r  \
# 0    [national, archives, yes, it’s, time, folks, i...
# 1    [los, angeles, ap, —, first, interview, since,...
# 2    [gaithersburg, md, ap, —, small, private, jet,...
# 3    [tucker, carlson, exposes, sexism, twitter, up...
# 4    [man, accused, removing, another, mans, testic...
# ..                                                 ...
# 995  [ournalist, nedim, turfent, reporting, brutal,...
# 996  [ramallah, west, bank, ap, —, witness, says, m...
# 997  [you’ve, ever, thought, birth, control, might,...
# 998  [friends, say, surprise, reconciliation, cards...
# 999  [2005, witherspoon, school, law, public, polic...
#
#                                  document_lemmatized_s  \
# 0    [national, archives, yes, it’s, time, folks, i...
# 1    [los, angeles, ap, —, first, interview, since,...
# 2    [gaithersburg, md, ap, —, small, private, jet,...
# 3    [tucker, carlson, exposes, sexism, twitter, up...
# 4    [man, accused, removing, another, mans, testic...
# ..                                                 ...
# 995  [ournalist, nedim, turfent, reporting, brutal,...
# 996  [ramallah, west, bank, ap, —, witness, says, m...
# 997  [you’ve, ever, thought, birth, control, might,...
# 998  [friends, say, surprise, reconciliation, cards...
# 999  [2005, witherspoon, school, law, public, polic...
#
#                                  document_lemmatized_n
# 0    [national, archive, yes, it’s, time, folk, it’...
# 1    [los, angeles, ap, —, first, interview, since,...
# 2    [gaithersburg, md, ap, —, small, private, jet,...
# 3    [tucker, carlson, expose, sexism, twitter, upd...
# 4    [man, accused, removing, another, man, testicl...
# ..                                                 ...
# 995  [ournalist, nedim, turfent, reporting, brutal,...
# 996  [ramallah, west, bank, ap, —, witness, say, me...
# 997  [you’ve, ever, thought, birth, control, might,...
# 998  [friend, say, surprise, reconciliation, card, ...
# 999  [2005, witherspoon, school, law, public, polic...
#
# [1000 rows x 11 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
# Term Frequency-Inverse Document Frequency (TF-IDF)
# Step 1: join tokens into strings
train_docs_joined = train_ds['document_lemmatized_n'].apply(lambda tokens: ' '.join(tokens))
test_docs_joined = test_ds['document_lemmatized_n'].apply(lambda tokens: ' '.join(tokens))

# Step 2: fit the vectorizer
vectorizer = CountVectorizer()
vectorizer.fit(train_docs_joined)

# Optional: print vocabulary
print('Vocabulary:', vectorizer.vocabulary_)

# Step 3: transform the joined strings
vector_train = vectorizer.transform(train_docs_joined)
vector_test = vectorizer.transform(test_docs_joined)
# Out:
# Vocabulary: {'national': 35939, 'archive': 6583, 'yes': 57879, 'it': 28586, 'time': 52664, 'folk': 21526, 'first': 21091, 'friday': 22059, 'month': 35013, 'one': 37806, 'eversobrief': 19635, 'moment': 34890, 'interest': 28096, 'wall': 56162, 'street': 50319, 'washington': 56293, 'main': 32626, 'aligned': 5345, 'thing': 52324, 'job': 29102, 'fresh': 22038, 'update': 54976, 'employment': 18811, 'situation': 48213, 'january': 28800, 'hit': 25623, 'wire': 57142, '830': 3726, 'new': 36351, 'york': 57949, 'offering': 37556, 'important': 27226, 'snapshot': 48703, 'economy': 18232, 'fared': 20419, 'previous': 41546, 'expectation': 19902, '203000': 1646, 'created': 14492, 'according': 4378, 'economist': 18231, 'polled': 40786, 'dow': 17524, 'jones': 29191, 'newswires': 36426, 'compared': 13196, '227000': 1785, 'added': 4558, 'february': 20641, 'unemployment': 54531, 'rate': 42984, 'expected': 19905, 'hold': 25733, 'steady': 49913, '83': 3725, 'marketbeat': 33050, 'hq': 26090, 'we': 56425, 'll': 31761, 'color': 12985, 'commentary': 13113, 'data': 15313, 'cross': 14648, 'feel': 20682, 'free': 21981, 'weighin': 56560, 'via': 55611, 'comment': 13112, 'section': 46773, 'you': 57963, 're': 43079, 'don': 17362, 'sign': 47968, 'follow': 21536, 'twitter': 53982, 'enjoy': 19012, 'show': 47788, 'employer': 18809, 'pulled': 42225, 'back': 7545, 'sharply': 47479, 'hiring': 25594, 'last': 30752, 'reminder': 43977, 'may': 33370, 'growing': 23962, 'fast': 20485, 'enough': 19040, 'sustain': 51086, 'robust': 45091, 'growth': 23968, 'dipped': 16673, 'mostly': 